# %%
import cdsapi
c = cdsapi.Client()
print(c)
# Out:
# 2025-05-16 22:56:45,969 WARNING [2025-05-15T00:00:00] Scheduled maintenance of the Data Stores Cloud Infrastructure - 19 May 2025. Please follow status [here](https://status.ecmwf.int/) or in our [forum](https://forum.ecmwf.int/t/scheduled-maintenance-of-the-data-stores-cloud-infrastructure-19-may-2025/13056/1)
# 2025-05-16 22:56:45,970 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# ...

# %%
import os 
import dotenv
dotenv.load_dotenv()

# Get the environment variables
api_key = os.getenv('CDS_ADS_API_KEY')

# %%
import cdsapi

dataset = "cems-fire-seasonal"
request = {
    "data_format": "grib"
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# 2025-05-16 23:19:57,867 WARNING [2025-05-15T00:00:00] Scheduled maintenance of the Data Stores Cloud Infrastructure - 19 May 2025. Please follow status [here](https://status.ecmwf.int/) or in our [forum](https://forum.ecmwf.int/t/scheduled-maintenance-of-the-data-stores-cloud-infrastructure-19-may-2025/13056/1)
# 2025-05-16 23:19:57,868 INFO [2024-09-26T00:00:00] Watch our [Forum]( https://forum.ecmwf.int/) for Announcements, news and other discussed topics.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 import cdsapi
#       3 c = cdsapi.Client()
# ----> 5 c.retrieve(
#       6     'cams-global-greenhouse-gas-forecasts',
#       7     {
#       8         # Must be a list of one “range” string
#       9         'date': ['2025-05-12/2025-05-12'],
#      10         'variable': ['Multi-level chemical'],
# ...
